# %% [markdown]
# # Dataset Telco Customer Churn
# Link: https://www.kaggle.com/datasets/blastchar/telco-customer-churn

# %%
# !git clone https://github.com/qtrong0205/customer-churn-analysis
# Out:
# Cloning into 'customer-churn-analysis'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 16 (delta 1), reused 11 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 51.02 KiB | 3.40 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd customer-churn-analysis
# Out:
# /content/customer-churn-analysis

# %%
import pandas as pd
raw_data = pd.read_csv("./data/churn.csv")
raw_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
raw_data.shape
# Out:
# (7043, 21)

# %%
raw_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
raw_data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **Cột custumerID không cần thiết --> có thể xoá**

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
raw_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# **Kiểm tra missing values**

# %%
raw_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# **Phân tích target**

# %%
raw_data["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
raw_data["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# Điều này cho thấy gần 27% khách hành churn

# %%
target = raw_data["Churn"]

# %%
numerical_cols = ["tenure", "MonthlyCharges", "TotalCharges"]

# %%
import matplotlib.pyplot as plt

# %%
for col in numerical_cols:
    plt.figure(figsize=(6,4))
    plt.hist(raw_data[col], bins=30, edgecolor='black')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# **Phân tích feature và target**

# %%
import seaborn as sns

sns.countplot(x="Churn", data=raw_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# **Số lượng "No" lớn hơn nhiều so với "Yes", accuracy sẽ không đáng tin**

# %%
sns.boxplot(x="Churn", y="tenure", data=raw_data)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# Khách hàng tenure thấp có tỷ lệ churn cao hơn

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data=raw_data)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
pd.crosstab(raw_data["Contract"], raw_data["Churn"])
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
sns.countplot(x="Contract", hue="Churn", data=raw_data)
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# Những người có hợp đồng ngắn hạn có tỷ lệ Churn cao hơn

# %%
sns.boxplot(x=raw_data["MonthlyCharges"])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %% [markdown]
# # Tổng kết
# 1. Tập dữ liệu chứa một đặc điểm định danh (customerID) không hữu ích cho việc dự đoán và sẽ bị loại bỏ.
#
# 2. Biến mục tiêu (Churn) không cân bằng, với số trường hợp "Không" nhiều hơn đáng kể so với "Có".
#
# 3. Khách hàng có thời gian sử dụng dịch vụ ngắn hơn có xu hướng rời bỏ dịch vụ thường xuyên hơn, cho thấy khách hàng mới có nhiều khả năng rời đi hơn.
#
# 4. Khách hàng có hợp đồng hàng tháng có tỷ lệ rời bỏ dịch vụ cao hơn nhiều so với những khách hàng có hợp đồng dài hạn.
#
# 5. Khách hàng có phí hàng tháng cao hơn dường như rời bỏ dịch vụ thường xuyên hơn.
#
# 6. Một số đặc điểm số như MonthlyCharges và TotalCharges có thể cần được hiệu chỉnh tỷ lệ tùy thuộc vào thuật toán máy học được sử dụng.
